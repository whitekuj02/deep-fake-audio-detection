# %%
import torch
from torch.utils.data import DataLoader, Dataset
import torchaudio
from transformers import AutoFeatureExtractor, ASTForAudioClassification
from glob import glob
from collections import defaultdict
from tqdm import tqdm

# %%
# Define dataset class
class AudioDataset(Dataset):
    def __init__(self, file_paths, feature_extractor, target_sampling_rate=16000):
        self.file_paths = file_paths
        self.feature_extractor = feature_extractor
        self.target_sampling_rate = target_sampling_rate

    def __len__(self):
        return len(self.file_paths)

    def __getitem__(self, idx):
        file_path = self.file_paths[idx]
        data, sr = torchaudio.load(file_path)
        data = torchaudio.functional.resample(data, orig_freq=sr, new_freq=self.target_sampling_rate)
        data = data.squeeze()
        inputs = self.feature_extractor(data, sampling_rate=self.target_sampling_rate, return_tensors="pt")
        inputs['input_values'] = inputs['input_values'].squeeze(0)  # Remove batch dimension
        return inputs['input_values'], file_path

# %%
# Inference function
def inference_batch(model, dataloader, k=5, with_logit=False):
    d = defaultdict(int)
    counts = 0
    tqdm_bar = tqdm(dataloader)

    with open("/root/asset/test_only_speech_list_k5.txt", "w") as tf:
        for batch, paths in tqdm_bar:
            batch = batch.to('cuda:0')
            with torch.no_grad():
                outputs = model(input_values=batch).logits

            for i, logits in enumerate(outputs):
                logits = logits.squeeze()
                predicted_class_ids = torch.argsort(logits)[-k:]
                predicted_labels = [model.config.id2label[_id.item()] for _id in predicted_class_ids]

                for label in predicted_labels:
                    d[label] += 1

                #list_of_lists = [str(tensor.tolist()) for tensor in sorted(logits)[-k:]]
                sorted_indices = torch.argsort(logits)

                # 0의 정렬된 인덱스에서의 위치를 찾음
                sorted_position = (sorted_indices == 0).nonzero(as_tuple=True)[0].item()

                # 뒤에서 몇 번째인지 계산
                reverse_position = len(logits) - sorted_position - 1
                zero_logit_value = logits[0].item()

                if reverse_position > 2 and zero_logit_value <= -2.5:
                    tf.write(paths[i] + " --> " + str(reverse_position) + " --> " + str(zero_logit_value) + "\n")
                    counts += 1
                    

            tqdm_bar.set_postfix(only_speech=d)

    return d, counts

# %%
# Load model and feature extractor
feature_extractor = AutoFeatureExtractor.from_pretrained("MIT/ast-finetuned-audioset-10-10-0.4593")
model = ASTForAudioClassification.from_pretrained("MIT/ast-finetuned-audioset-10-10-0.4593")
model = model.to('cuda:0')
model.eval()

# Parameters
batch_size = 32  # Adjust batch size according to your GPU memory
file_paths = glob("/root/data/test/*.ogg")
dataset = AudioDataset(file_paths, feature_extractor)
dataloader = DataLoader(dataset, batch_size=batch_size, shuffle=False)


# Run inference
d, counts = inference_batch(model, dataloader, k=5, with_logit=True)
print("Finished processing. Total non-speech files:", counts)
# Out:
# 100%|██████████| 1563/1563 [18:44<00:00,  1.39it/s, only_speech=defaultdict(<class 'int'>, {'Breaking': 903, 'Bang': 79, 'Burst, pop': 546, 'Explosion': 930, 'Speech': 44871, 'Narration, monologue': 8689, 'Female speech, woman speaking': 7520, 'Inside, small room': 7502, 'Animal': 8360, 'Sliding door': 366, 'Door': 1144, 'Stomach rumble': 237, 'Water': 2345, 'Knock': 1585, 'Slam': 235, 'Coin (dropping)': 416, 'Typing': 1187, 'Computer keyboard': 1384, 'Chop': 1063, 'Bouncing': 181, 'Typewriter': 543, 'Scissors': 262, 'Pig': 624, 'Oink': 1019, 'Grunt': 365, 'Music': 10563, 'Helicopter': 670, 'Vehicle': 8696, 'Speech synthesizer': 3380, 'Conversation': 6158, 'Tap': 930, 'Male speech, man speaking': 2607, 'Applause': 720, 'Clapping': 821, 'Tick': 1268, 'Tick-tock': 1097, 'Fill (with liquid)': 765, 'Liquid': 1901, 'Toilet flush': 943, 'Tools': 1023, 'Power tool': 588, 'Wood': 1363, 'Chainsaw': 703, 'Sigh': 554, 'Breathing': 469, 'Gasp': 1434, 'Snort': 1087, 'Chink, clink': 1430, 'Crack': 681, 'Cap gun': 354, 'Sound effect': 2354, 'Clock': 738, 'Cattle, bovinae': 954, 'Moo': 951, 'Livestock, farm animals, working animals': 1591, 'Wind chime': 61, 'Chime': 62, 'Mosquito': 513, 'Bee, wasp, etc.': 667, 'Fly, housefly': 880, 'Insect': 1404, 'Television': 637, 'Ping': 561, 'Rub': 1442, 'Sawing': 1024, 'Zipper (clothing)': 1599, 'Coo': 69, 'Pigeon, dove': 48, 'Bird': 1926, 'Squish': 314, 'Single-lens reflex camera': 1807, 'Church bell': 823, 'Bell': 1036, 'Change ringing (campanology)': 728, 'Jet engine': 613, 'Hair dryer': 393, 'Vacuum cleaner': 681, 'Caw': 988, 'Crow': 996, 'Mouse': 331, 'Cricket': 678, 'Toot': 383, 'Air horn, truck horn': 247, 'Vehicle horn, car horn, honking': 800, 'Outside, rural or natural': 261, 'Frog': 1260, 'Raindrop': 942, 'Rain': 1611, 'Rain on surface': 1504, 'Goat': 154, 'Bleat': 1061, 'Sheep': 1047, 'Aircraft': 1075, 'Boat, Water vehicle': 488, 'Motorboat, speedboat': 553, 'Car': 2183, 'Eruption': 673, 'Domestic animals, pets': 2357, 'Cat': 864, 'Meow': 836, 'Firecracker': 538, 'Fireworks': 591, 'Thunderstorm': 950, 'Thunder': 1020, 'Siren': 1026, 'Civil defense siren': 487, 'Emergency vehicle': 591, 'Chopping (food)': 980, 'Drip': 1520, 'Buzzer': 646, 'Alarm clock': 735, 'Alarm': 803, 'Beep, bleep': 417, 'Fixed-wing aircraft, airplane': 418, 'Propeller, airscrew': 398, 'Silence': 1735, 'Shatter': 305, 'Glass': 742, 'Sneeze': 117, 'Pant': 163, 'Roar': 141, 'Train': 1097, 'Hammer': 100, 'Outside, urban or manmade': 756, 'Crunch': 499, 'Tearing': 142, 'Crumpling, crinkling': 225, 'Fire engine, fire truck (siren)': 280, 'Police car (siren)': 426, 'Yip': 29, 'Bow-wow': 838, 'Spray': 323, 'Shuffling cards': 90, 'Accelerating, revving, vroom': 501, 'Fowl': 1845, 'Cluck': 1725, 'Chicken, rooster': 1760, 'Pink noise': 113, 'Wind': 540, 'Waves, surf': 918, 'Ocean': 938, 'Squeak': 469, 'Finger snapping': 324, 'Distortion': 24, 'Musical instrument': 229, 'Guitar': 16, 'Engine': 1821, 'Heavy engine (low frequency)': 447, 'Microwave oven': 57, 'Wheeze': 67, 'Burping, eructation': 133, 'Railroad car, train wagon': 775, 'Subway, metro, underground': 91, 'Gurgling': 288, 'Crying, sobbing': 35, 'Baby cry, infant cry': 154, 'Crowing, cock-a-doodle-doo': 1318, 'Throat clearing': 1109, 'Aircraft engine': 108, 'Rattle': 429, 'Motorcycle': 314, 'Slosh': 287, 'Crackle': 513, 'Walk, footsteps': 408, 'Throbbing': 184, 'Heart murmur': 150, 'Heart sounds, heartbeat': 295, 'Sanding': 162, 'Toothbrush': 618, 'Medium engine (mid frequency)': 842, 'Idling': 811, 'Hoot': 129, 'Wind noise (microphone)': 535, 'Biting': 456, 'Blender': 226, 'Whir': 326, 'Field recording': 101, 'Filing (rasp)': 470, 'Rail transport': 795, 'Creak': 342, 'Clickety-clack': 187, 'Theremin': 39, 'Gunshot, gunfire': 357, 'Chirp, tweet': 735, 'Bird vocalization, bird call, bird song': 752, 'Croak': 833, 'Dog': 1048, 'Cutlery, silverware': 199, 'Dishes, pots, and pans': 355, 'Smoke detector, smoke alarm': 122, 'Fire alarm': 91, 'Air conditioning': 294, 'Cowbell': 211 ...
# Finished processing. Total non-speech files: 6305

# %%
import pandas as pd

file_ids = []

with open("/root/asset/test_only_speech_list_k5.txt", "r") as file:
    for line in file:
        file_path = line.split(' ')[0]
        file_id = file_path.split('/')[-1].split('.')[0]
        file_ids.append(file_id.strip("\n"))

# Create a DataFrame
df = pd.DataFrame(file_ids, columns=['id'])

# Save to CSV
csv_path = "./infer_masking.csv"
df.to_csv(csv_path, index=False)

print(f"CSV file saved to {csv_path}")
# Out:
# CSV file saved to ./infer_masking.csv

# %%
import pandas as pd

# CSV 파일 읽기
df1 = pd.read_csv('./infer_masking.csv')
df2 = pd.read_csv('/root/asset/ex7_19/new_masking.csv')

# 'id' 열에 strip() 적용
df1['id'] = df1['id'].str.strip()
df2['id'] = df2['id'].str.strip()

# 'id' 열의 교집합 추출
common_ids = pd.merge(df1, df2, on='id')

# 교집합에 속하지 않는 'id' 찾기
df1_ids = set(df1['id'])
common_ids_set = set(common_ids['id'])
non_common_ids = df1_ids - common_ids_set

# 교집합에 속하지 않는 행 출력
for idx, row in df1.iterrows():
    if row['id'] in non_common_ids:
        print(row)

print(f"df1 : {len(df1)}, df2 : {len(df2)}, merge : {len(common_ids)}")
# Out:
# id    TEST_00191
# Name: 21, dtype: object
# id    TEST_00281
# Name: 33, dtype: object
# id    TEST_00351
# Name: 40, dtype: object
# id    TEST_00356
# Name: 42, dtype: object
# id    TEST_00575
# Name: 83, dtype: object
# id    TEST_00777
# Name: 109, dtype: object
# id    TEST_01004
# Name: 143, dtype: object
# id    TEST_01117
# Name: 151, dtype: object
# id    TEST_01145
# Name: 159, dtype: object
# id    TEST_01301
# Name: 177, dtype: object
# id    TEST_01815
# Name: 227, dtype: object
# id    TEST_02359
# Name: 307, dtype: object
# id    TEST_02549
# Name: 331, dtype: object
# id    TEST_02637
# Name: 341, dtype: object
# id    TEST_02740
# Name: 357, dtype: object
# id    TEST_02950
# Name: 379, dtype: object
# id    TEST_03045
# Name: 388, dtype: object
# id    TEST_03717
# Name: 468, dtype: object
# id    TEST_03781
# Name: 475, dtype: object
# id    TEST_04340
# Name: 539, dtype: object
# id    TEST_04425
# Name: 552, dtype: object
# id    TEST_04969
# Name: 638, dtype: object
# id    TEST_05001
# Name: 640, dtype: object
# id    TEST_05190
# Name: 669, dtype: object
# id    TEST_05335
# Name: 691, dtype: object
# id    TEST_05824
# Name: 755, dtype: object
# id    TEST_05978
# Name: 772, dtype: object
# id    TEST_06110
# Name: 788, dtype: object
# id    TEST_06135
# Name: 792, dtype: object
# id    TEST_06298
# Name: 815, dtype: object
# id    TEST_06999
# Name: 916, dtype: object
# id    TEST_07189
# Name: 943, dtype: object
# id    TEST_07255
# Name: 948, dtype: object
# id    TEST_07490
# Name: 969, dtype: object
# id    TEST_08639
# Name: 1100, dtype: object
# id    TEST_08849
# Name: 1130, dtype: object
# id    TEST_09151
# Name: 1162, dtype: object
# id    TEST_09180
# Name: 1170, dtype: object
# id    TEST_09755
# Name: 1250, dtype: object
# id    TEST_09778
# Name: 1254, dtype: object
# id    TEST_10232
# Name: 1320, dtype: object
# id    TEST_10586
# Name: 1360, dtype: object
# id    TEST_10819
# Name: 1382, dtype: object
# id    TEST_11150
# Name: 1423, dtype: object
# id    TEST_11262
# Name: 1443, dtype: object
# id    TEST_11263
# Name: 1444, dtype: object
# id    TEST_11264
# Name: 1445, dtype: object
# id    TEST_11273
# Name: 1446, dtype: object
# id    TEST_11274
# Name: 1447, dtype: object
# id    TEST_11290
# Name: 1450, dtype: object
# id    TEST_11325
# Name: 1455, dtype: object
# id    TEST_11430
# Name: 1465, dtype: object
# id    TEST_11872
# Name: 1517, dtype: object
# id    TEST_11999
# Name: 1534, dtype: object
# id    TEST_12018
# Name: 1539, dtype: object
# id    TEST_13170
# Name: 1678, dtype: object
# id    TEST_13545
# Name: 1726, dtype: object
# id    TEST_13954
# Name: 1780, dtype: object
# id    TEST_14396
# Name: 1837, dtype: object
# id    TEST_14800
# Name: 1885, dtype: object
# id    TEST_15267
# Name: 1958, dtype: object
# id    TEST_15283
# Name: 1961, dtype: object
# id    TEST_15895
# Name: 2040, dtype: object
# id    TEST_16108
# Name: 2068, dtype: object
# id    TEST_16518
# Name: 2119, dtype: object
# id    TEST_16679
# Name: 2142, dtype: object
# id    TEST_16701
# Name: 2143, dtype: object
# id    TEST_16713
# Name: 2146, dtype: object
# id    TEST_16764
# Name: 2156, dtype: object
# id    TEST_16819
# Name: 2165, dtype: object
# id    TEST_17033
# Name: 2189, dtype: object
# id    TEST_17098
# Name: 2200, dtype: object
# id    TEST_17102
# Name: 2201, dtype: object
# id    TEST_17647
# Name: 2276, dtype: object
# id    TEST_18396
# Name: 2370, dtype: object
# id    TEST_18475
# Name: 2378, dtype: object
# id    TEST_18600
# Name: 2395, dtype: object
# id    TEST_18687
# Name: 2406, dtype: object
# id    TEST_18779
# Name: 2419, dtype: object
# id    TEST_19311
# Name: 2479, dtype: object
# id    TEST_20188
# Name: 2584, dtype: object
# id    TEST_20611
# Name: 2625, dtype: object
# id    TEST_20647
# Name: 2631, dtype: object
# id    TEST_20748
# Name: 2642, dtype: object
# id    TEST_21208
# Name: 2705, dtype: object
# id    TEST_21343
# Name: 2717, dtype: object
# id    TEST_21544
# Name: 2739, dtype: object
# id    TEST_21610
# Name: 2750, dtype: object
# id    TEST_21623
# Name: 2754, dtype: object
# id    TEST_22012
# Name: 2802, dtype: object
# id    TEST_22937
# Name: 2916, dtype: object
# id    TEST_23153
# Name: 2948, dtype: object
# id    TEST_23176
# Name: 2950, dtype: object
# id    TEST_23438
# Name: 2982, dtype: object
# id    TEST_23534
# Name: 2997, dtype: object
# id    TEST_23590
# Name: 3009, dtype: object
# id    TEST_23803
# Name: 3040, dtype: object
# id    TEST_24057
# Name: 3065, dtype: object
# id    TEST_25170
# Name: 3192, dtype: object
# id    TEST_25486
# Name: 3221, dtype: object
# id    TEST_27042
# Name: 3428, dtype: object
# id    TEST_27471
# Name: 3489, dtype: object
# id    TEST_27511
# Name: 3496, dtype: object
# id    TEST_27778
# Name: 3528, dtype: object
# id    TEST_28635
# Name: 3624, dtype: object
# id    TEST_28814
# Name: 3644, dtype: object
# id    TEST_29059
# Name: 3670, dtype: object
# id    TEST_29354
# Name: 3702, dtype: object
# id    TEST_29725
# Name: 3745, dtype: object
# id    TEST_29813
# Name: 3756, dtype: object
# id    TEST_30009
# Name: 3777, dtype: object
# id    TEST_30148
# Name: 3797, dtype: object
# id    TEST_30577
# Name: 3842, dtype: object
# id    TEST_30609
# Name: 3847, dtype: object
# id    TEST_30814
# Name: 3879, dtype: object
# id    TEST_31508
# Name: 3962, dtype: object
# id    TEST_32239
# Name: 4054, dtype: object
# id    TEST_33313
# Name: 4192, dtype: object
# id    TEST_33647
# Name: 4239, dtype: object
# id    TEST_33708
# Name: 4243, dtype: object
# id    TEST_34140
# Name: 4303, dtype: object
# id    TEST_34631
# Name: 4355, dtype: object
# id    TEST_34773
# Name: 4372, dtype: object
# id    TEST_34799
# Name: 4377, dtype: object
# id    TEST_34849
# Name: 4383, dtype: object
# id    TEST_34876
# Name: 4388, dtype: object
# id    TEST_34952
# Name: 4394, dtype: object
# id    TEST_35433
# Name: 4462, dtype: object
# id    TEST_35489
# Name: 4472, dtype: object
# id    TEST_35774
# Name: 4508, dtype: object
# id    TEST_36026
# Name: 4541, dtype: object
# id    TEST_36044
# Name: 4543, dtype: object
# id    TEST_36375
# Name: 4592, dtype: object
# id    TEST_36570
# Name: 4625, dtype: object
# id    TEST_36590
# Name: 4631, dtype: object
# id    TEST_36992
# Name: 4672, dtype: object
# id    TEST_37160
# Name: 4685, dtype: object
# id    TEST_37180
# Name: 4688, dtype: object
# id    TEST_37503
# Name: 4730, dtype: object
# id    TEST_37600
# Name: 4742, dtype: object
# id    TEST_38119
# Name: 4808, dtype: object
# id    TEST_38342
# Name: 4839, dtype: object
# id    TEST_38362
# Name: 4844, dtype: object
# id    TEST_39871
# Name: 5039, dtype: object
# id    TEST_40023
# Name: 5060, dtype: object
# id    TEST_40049
# Name: 5062, dtype: object
# id    TEST_40261
# Name: 5090, dtype: object
# id    TEST_40526
# Name: 5123, dtype: object
# id    TEST_40704
# Name: 5145, dtype: object
# id    TEST_40956
# Name: 5173, dtype: object
# id    TEST_40967
# Name: 5175, dtype: object
# id    TEST_41286
# Name: 5216, dtype: object
# id    TEST_41821
# Name: 5289, dtype: object
# id    TEST_42119
# Name: 5320, dtype: object
# id    TEST_42196
# Name: 5334, dtype: object
# id    TEST_42302
# Name: 5346, dtype: object
# id    TEST_42303
# Name: 5347, dtype: object
# id    TEST_42490
# Name: 5377, dtype: object
# id    TEST_42519
# Name: 5382, dtype: object
# id    TEST_42771
# Name: 5417, dtype: object
# id    TEST_42846
# Name: 5431, dtype: object
# id    TEST_42931
# Name: 5444, dtype: object
# id    TEST_42967
# Name: 5448, dtype: object
# id    TEST_43210
# Name: 5478, dtype: object
# id    TEST_44290
# Name: 5603, dtype: object
# id    TEST_44338
# Name: 5610, dtype: object
# id    TEST_44790
# Name: 5663, dtype: object
# id    TEST_45193
# Name: 5716, dtype: object
# id    TEST_45298
# Name: 5726, dtype: object
# id    TEST_46303
# Name: 5868, dtype: object
# id    TEST_47228
# Name: 5963, dtype: object
# id    TEST_47553
# Name: 6006, dtype: object
# id    TEST_47669
# Name: 6023, dtype: object
# id    TEST_47759
# Name: 6039, dtype: object
# id    TEST_47779
# Name: 6041, dtype: object
# id    TEST_48065
# Name: 6085, dtype: object
# id    TEST_48291
# Name: 6112, dtype: object
# id    TEST_48538
# Name: 6140, dtype: object
# id    TEST_48624
# Name: 6147, dtype: object
# id    TEST_49008
# Name: 6194, dtype: object
# df1 : 6305, df2 : 6469, merge : 6125
